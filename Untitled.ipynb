# %% [markdown]
# ## 1. Import the required Libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## DATA SET - 1

# %% [markdown]
# ##  Loading and understanding the data

# %%
#Read the data in pandas
inp0 = pd.read_csv("diabetes_prediction_dataset.csv")

# %%
inp0
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
inp0.shape
# Out:
# (100000, 9)

# %%
# Discovering the data types
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
inp0.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %% [markdown]
# #### The data have no null values and anomilities and is ready for analysis.

# %% [markdown]
# ##  Univariate Analysis

# %% [markdown]
# ### Gender

# %%
More females are surveyed here
# Out:
# Female    58552
# Male      41430
# Other        18
# Name: gender, dtype: int64

# %%
inp0['gender'].value_counts(normalize = True)*100
# Out:
# Female    58.552
# Male      41.430
# Other      0.018
# Name: gender, dtype: float64

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Gender Distribution")

# Bar char showing gender distribution
sns.countplot(x='gender', data=inp0)

# Add label for vertical axis
plt.ylabel("counts")

plt.show()

# %% [markdown]
# Gender Distribution: The dataset suggests that females represent the majority, accounting for 58% of the population.
#
# Gender Imbalance: There appears to be a gender imbalance in the dataset, with females being more prevalent compared to other genders.
#
# Gender Bias: The dataset might reflect a bias towards females, either due to the sampling method or the nature of the data collection process.

# %% [markdown]
# ### Age

# %%
inp0['age'].value_counts(normalize = True)*100
# Out:
# 80.00    5.621
# 51.00    1.619
# 47.00    1.574
# 48.00    1.568
# 53.00    1.542
#          ...
# 0.48     0.083
# 1.00     0.083
# 0.40     0.066
# 0.16     0.059
# 0.08     0.036
# Name: age, Length: 102, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=inp0, x='age', kde=True)
plt.xlabel('Age')
plt.ylabel('Density')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# The dataset is prominently dominated by individuals aged 80.00, constituting the highest occurrence rate of 5.621%.
#
# Remarkably, the second most prevalent age group is 51.00, but with a considerably lower occurrence rate of 1.619%. This suggests that a substantial number of participants surveyed were 80 years old, contributing to their significant representation in the dataset.

# %% [markdown]
# ### hypertension

# %%
plt.figure(figsize=(10,6))
# Calculate the value counts and percentages for 'hypertension' column
hypertension_counts = inp0['hypertension'].value_counts()
hypertension_percentages = hypertension_counts / len(inp0) * 100

# Define custom colors
custom_colors = ['#1F77B4','#FFA500']  # Orange and Blue

# Plot the pie chart with custom colors
plt.figure(figsize=(8, 6))
plt.title('Hypertension Distribution')
plt.pie(hypertension_percentages, labels=hypertension_percentages.index, autopct='%1.1f%%', colors=custom_colors)
plt.axis('equal')  # Ensure pie is drawn as a circle
plt.show()

# %% [markdown]
# Approximately 7.5% of the survey participants were found to have hypertension.

# %% [markdown]
# ### heart_disease

# %%
plt.figure(figsize=(10,6))
# Calculate the value counts and percentages for 'hypertension' column
hypertension_counts = inp0['heart_disease'].value_counts()
hypertension_percentages = hypertension_counts / len(inp0) * 100

# Define custom colors
custom_colors = ['#1F77B4','#FFA500']  # Orange and Blue

# Plot the pie chart with custom colors
plt.figure(figsize=(8, 6))
plt.title('heart_disease Distribution')
plt.pie(hypertension_percentages, labels=hypertension_percentages.index, autopct='%1.1f%%', colors=custom_colors)
plt.axis('equal')  # Ensure pie is drawn as a circle
plt.show()

# %% [markdown]
# Approximately 4% of the survey participants were found to have heart disease.

# %% [markdown]
# ### smoking_history

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=inp0, x='smoking_history')
plt.title('Distribution of Smoking History')
plt.xlabel('Smoking History')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.show()

# %%
inp0.smoking_history.value_counts()
# Out:
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: smoking_history, dtype: int64

# %% [markdown]
# The majority of survey participants have missing or no information regarding their smoking history, with a count of 35,816.
#
# The second most common category is "never," indicating that a significant number of participants have never smoked, with a count of 35,095.
#
# A notable portion of participants are former smokers, as indicated by the "former" category with a count of 9,352.
#
# The number of participants who are currently smoking is relatively close to the count of former smokers, with a count of 9,286 for the "current" category.
#
# A smaller portion of participants are classified as "not current" smokers, with a count of 6,447.
#
# The category "ever" represents participants who have smoked at some point in their lives, with a count of 4,004.

# %% [markdown]
# ### BMI

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=inp0, x='bmi', bins=20, kde=True)
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Count')
plt.show()

# %%
a = inp0.bmi.value_counts(normalize=True)*100
a
# Out:
# 27.32    25.495
# 23.00     0.103
# 27.12     0.101
# 27.80     0.100
# 24.96     0.100
#           ...
# 58.23     0.001
# 48.18     0.001
# 55.57     0.001
# 57.07     0.001
# 60.52     0.001
# Name: bmi, Length: 4247, dtype: float64

# %% [markdown]
# The most common BMI value is 27.32, representing approximately 25.495% of the participants. This indicates that a significant proportion of participants fall within this BMI range.
#
# There are several other BMI values with relatively low percentages, indicating a diverse range of BMI values among the participants.
#
# The remaining BMI values have extremely low percentages (ranging from 0.001% to 0.103%), suggesting that they occur infrequently in the dataset.

# %% [markdown]
# ### blood_glucose_level

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=inp0, x='blood_glucose_level', bins=20, kde=True)
plt.title('Blood Glucose Level Distribution')
plt.xlabel('Blood Glucose Level')
plt.ylabel('Count')
plt.show()

# %%
inp0.blood_glucose_level.value_counts(normalize=True)*100
# Out:
# 130    7.794
# 159    7.759
# 140    7.732
# 160    7.712
# 126    7.702
# 145    7.679
# 200    7.600
# 155    7.575
# 90     7.112
# 80     7.106
# 158    7.026
# 100    7.025
# 85     6.901
# 280    0.729
# 300    0.674
# 240    0.636
# 260    0.635
# 220    0.603
# Name: blood_glucose_level, dtype: float64

# %% [markdown]
# The highest blood glucose level in the dataset is 300, which has a relatively low occurrence percentage of 0.674%.
#
# There is a gradual decrease in occurrence percentages as the blood glucose levels decrease from 160 to 85, with the lowest percentages observed for levels below 100.

# %% [markdown]
# ### diabetes

# %%
plt.figure(figsize=(8, 6))
sns.set_style('whitegrid')
sns.countplot(data=inp0, x='diabetes', palette='Set2')
plt.title('Distribution of Diabetes')
plt.xlabel('Diabetes')
plt.ylabel('Count')
plt.show()

# %%
inp0.diabetes.value_counts(normalize=True)*100
# Out:
# 0    91.5
# 1     8.5
# Name: diabetes, dtype: float64

# %% [markdown]
# The majority of participants, approximately 91.5%, have a value of 0 in the 'diabetes' column. This indicates that the majority of participants are classified as non-diabetic.
#
# A smaller proportion of participants, approximately 8.5%, have a value of 1 in the 'diabetes' column. This suggests that a minority of participants are classified as diabetic.

# %% [markdown]
# ##  Multivariate Analysis

# %% [markdown]
# ### Gender and diabetics

# %%
plt.figure(figsize=(8, 6))
sns.set_style('whitegrid')
sns.countplot(data=inp0, x='gender', hue='diabetes', palette='Set2')
plt.title('Diabetes Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Diabetes', labels=['Non-Diabetic', 'Diabetic'])
plt.show()

# %%
cross_table = pd.crosstab(inp0['gender'], inp0['diabetes'], normalize='index')
print(cross_table)
# Out:
# diabetes         0         1
# gender
# Female    0.923811  0.076189
# Male      0.902510  0.097490
# Other     1.000000  0.000000

# %% [markdown]
# Among females, approximately 92.38% are classified as non-diabetic (diabetes=0), while approximately 7.62% are classified as diabetic (diabetes=1).
#
# Among males, approximately 90.25% are classified as non-diabetic, and approximately 9.75% are classified as diabetic.

# %% [markdown]
# ### Age and diabetics

# %%
diabetic_age_stats = inp0.loc[inp0['diabetes'] == 1, 'age'].describe()
non_diabetic_age_stats = inp0.loc[inp0['diabetes'] == 0, 'age'].describe()

print("Diabetic Age Statistics:")
print(diabetic_age_stats)

print("\nNon-Diabetic Age Statistics:")
print(non_diabetic_age_stats)
# Out:
# Diabetic Age Statistics:
# count    8500.000000
# mean       60.946588
# std        14.549880
# min         3.000000
# 25%        52.000000
# 50%        62.000000
# 75%        72.000000
# max        80.000000
# Name: age, dtype: float64
#
# Non-Diabetic Age Statistics:
# count    91500.000000
# mean        40.115187
# std         22.306005
# min          0.080000
# 25%         22.000000
# 50%         40.000000
# 75%         57.000000
# max         80.000000
# Name: age, dtype: float64

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=inp0, x='diabetes', y='age')
plt.title('Age Distribution by Diabetes Status')
plt.xlabel('Diabetes')
plt.ylabel('Age')
plt.xticks([0, 1], ['Non-Diabetic', 'Diabetic'])
plt.show()

# %% [markdown]
# #### Diabetic Age Statistics:
#
# The count of diabetic individuals is 8,500.
#
# The mean age of diabetic individuals is approximately 60.95 years.
#
# The standard deviation of age among diabetic individuals is approximately 14.55, indicating some variation around the mean.
# The minimum age observed among diabetic individuals is 3 years, while the maximum age is 80 years.
#
#
# The 25th percentile (Q1) is 52 years, meaning that 25% of the diabetic individuals are 52 years old or younger.
#
# The median age (50th percentile or Q2) is 62 years, representing the middle value of the age distribution for diabetic individuals.
#
# The 75th percentile (Q3) is 72 years, indicating that 75% of the diabetic individuals are 72 years old or younger.
#
#
# #### Non-Diabetic Age Statistics:
#
# The count of non-diabetic individuals is 91,500.
#
# The mean age of non-diabetic individuals is approximately 40.12 years, significantly lower than the mean age of diabetic individuals.
#
# The standard deviation of age among non-diabetic individuals is approximately 22.31, suggesting a relatively higher variation in age compared to the diabetic group.
#
# The minimum age observed among non-diabetic individuals is 0.08 years, while the maximum age is 80 years.
#
# The 25th percentile (Q1) is 22 years, indicating that 25% of the non-diabetic individuals are 22 years old or younger.
#
# The median age (50th percentile or Q2) is 40 years, representing the middle value of the age distribution for non-diabetic individuals.
#
# The 75th percentile (Q3) is 57 years, implying that 75% of the non-diabetic individuals are 57 years old or younger.
#
# ##### Based on these observations, it appears that the mean age of diabetic individuals is higher than that of non-diabetic individuals. Additionally, the distribution of ages among diabetic individuals seems to be more concentrated towards older ages, as evidenced by the higher values of the median, 75th percentile, and maximum age.
#
# Further analysis, such as hypothesis testing, can be conducted to determine the significance of the age difference between diabetic and non-diabetic groups and to explore the relationship between age and diabetes in more depth.

# %% [markdown]
# ### smoking_history and diabetes

# %%
cross_table = pd.crosstab(inp0['smoking_history'], inp0['diabetes'], normalize='index')
print(cross_table)
# Out:
# diabetes                0         1
# smoking_history
# No Info          0.959404  0.040596
# current          0.897911  0.102089
# ever             0.882118  0.117882
# former           0.829983  0.170017
# never            0.904659  0.095341
# not current      0.892973  0.107027

# %%
plt.figure(figsize=(18, 10))
sns.countplot(data=inp0, x='smoking_history', hue='diabetes', palette='Set2')
plt.title('Diabetes Distribution by Smoking History')
plt.xlabel('Smoking History')
plt.ylabel('Count')
plt.legend(title='Diabetes', labels=['Non-Diabetic', 'Diabetic'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# No Info:
#
# Approximately 95.94% of individuals with "No Info" smoking history are classified as non-diabetic (diabetes=0), while approximately 4.06% are classified as diabetic (diabetes=1).
# Current:
#
# Among individuals with a current smoking history, approximately 89.79% are classified as non-diabetic, and approximately 10.21% are classified as diabetic.
# Ever:
#
# Approximately 88.21% of individuals with a history of ever smoking are classified as non-diabetic, while approximately 11.78% are classified as diabetic.
# Former:
#
# Among individuals with a former smoking history, approximately 82.99% are classified as non-diabetic, and approximately 17.00% are classified as diabetic.
# Never:
#
# Approximately 90.47% of individuals who never smoked are classified as non-diabetic, while approximately 9.53% are classified as diabetic.
# Not Current:
#
# Among individuals with a non-current smoking history, approximately 89.30% are classified as non-diabetic, and approximately 10.70% are classified as diabetic.
# These statistics provide insights into the distribution of diabetes across different smoking history categories. It appears that individuals with a history of smoking (current, ever, former) generally have a higher proportion of diabetic individuals compared to those with no smoking history (never, not current). However, further analysis and statistical tests are needed to determine the significance of these differences and the impact of smoking history on diabetes prevalence.
#
# It's important to note that the interpretation of these findings should consider the sample size and the representativeness of the dataset. Additionally, the context and specific goals of the analysis should be taken into account when interpreting the relationship between smoking history and diabetes.

# %% [markdown]
# ### Correlation

# %%
columns = ['bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes']
data = inp0[columns]

# Compute the correlation matrix
corr_matrix = data.corr()

# Create the correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
corr_matrix
# Out:
#                           bmi  HbA1c_level  blood_glucose_level  diabetes
# bmi                  1.000000     0.082997             0.091261  0.214357
# HbA1c_level          0.082997     1.000000             0.166733  0.400660
# blood_glucose_level  0.091261     0.166733             1.000000  0.419558
# diabetes             0.214357     0.400660             0.419558  1.000000

# %% [markdown]
# BMI and Diabetes: The correlation coefficient between BMI and diabetes is 0.214. This positive correlation suggests a weak to moderate positive relationship between BMI and the presence of diabetes. It indicates that as BMI increases, the likelihood of having diabetes also tends to increase.
#
# HbA1c_level and Diabetes: The correlation coefficient between HbA1c_level and diabetes is 0.401. This positive correlation indicates a moderate positive relationship between HbA1c_level and the presence of diabetes. Higher levels of HbA1c are associated with an increased likelihood of having diabetes.
#
# Blood_glucose_level and Diabetes: The correlation coefficient between blood_glucose_level and diabetes is 0.420. This positive correlation suggests a moderate positive relationship between blood_glucose_level and the presence of diabetes. Higher blood glucose levels are associated with an increased likelihood of having diabetes.
#
# Overall, the correlation matrix provides insights into the relationships between BMI, HbA1c_level, blood_glucose_level, and diabetes. The strongest correlation is observed between blood_glucose_level and diabetes, followed by HbA1c_level and diabetes. BMI also shows a moderate positive correlation with diabetes. These findings indicate that these variables are positively associated with the presence of diabetes, although the strength of the correlations may vary. However, it's important to note that correlation does not imply causation, and further analysis is needed to establish causal relationships and consider other factors that may influence diabetes.

# %% [markdown]
# ## DATA SET 2

# %% [markdown]
# ## Loading and understanding the data

# %%
inp1 = pd.read_csv('India_rainfall_act_dep_1901_2016_1.csv')

# %%
inp1.head()
# Out:
#    YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0  1901                 109.1                 241.4                 284.2
# 1  1902                 104.0                 283.7                 202.6
# 2  1903                 114.8                 293.0                 279.6
# 3  1904                 158.8                 266.4                 210.4
# 4  1905                  88.7                 252.5                 202.6
#
#    Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 0                  121.9                      756.6
# 1                  201.9                      792.1
# 2                  204.4                      891.9
# 3                  129.6                      765.2
# 4                  174.6                      718.5
#
#    Departure Percentage: JUN  Departure Percentage: JUL  \
# 0                      -29.9                      -16.7
# 1                      -33.6                       -2.0
# ...

# %%
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   YEAR                            116 non-null    int64
#  1   Actual Rainfall: JUN            116 non-null    float64
#  2   Actual Rainfall: JUL            116 non-null    float64
#  3   Actual Rainfall: AUG            116 non-null    float64
#  4   Actual Rainfall: SEPT           116 non-null    float64
#  5   Actual Rainfall: JUN-SEPT       116 non-null    float64
#  6   Departure Percentage: JUN       116 non-null    float64
#  7   Departure Percentage: JUL       116 non-null    float64
#  8   Departure Percentage: AUG       116 non-null    float64
#  9   Departure Percentage: SEP       116 non-null    float64
#  10  Departure Percentage: JUN-SEPT  116 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 10.1 KB

# %%
inp1.dtypes
# Out:
# YEAR                                int64
# Actual Rainfall: JUN              float64
# Actual Rainfall: JUL              float64
# Actual Rainfall: AUG              float64
# Actual Rainfall: SEPT             float64
# Actual Rainfall: JUN-SEPT         float64
# Departure Percentage: JUN         float64
# Departure Percentage: JUL         float64
# Departure Percentage: AUG         float64
# Departure Percentage: SEP         float64
# Departure Percentage: JUN-SEPT    float64
# dtype: object

# %%
inp1.isnull().sum()
# Out:
# YEAR                              0
# Actual Rainfall: JUN              0
# Actual Rainfall: JUL              0
# Actual Rainfall: AUG              0
# Actual Rainfall: SEPT             0
# Actual Rainfall: JUN-SEPT         0
# Departure Percentage: JUN         0
# Departure Percentage: JUL         0
# Departure Percentage: AUG         0
# Departure Percentage: SEP         0
# Departure Percentage: JUN-SEPT    0
# dtype: int64

# %%
summary_stats = inp1.describe()
summary_stats
# Out:
#               YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  \
# count   116.000000            116.000000            116.000000
# mean   1958.500000            166.711207            294.135345
# std      33.630343             36.133349             41.531085
# min    1901.000000             85.700000            146.200000
# 25%    1929.750000            141.425000            273.575000
# 50%    1958.500000            167.250000            295.600000
# 75%    1987.250000            190.450000            322.400000
# max    2016.000000            277.200000            381.600000
#
#        Actual Rainfall: AUG  Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# count            116.000000             116.000000                 116.000000
# mean             260.920690             173.710345                 895.943966
# std               37.237717              37.492936                  92.796977
# min              189.800000              95.100000                 697.400000
# ...

# %%
# Data for the statistics
statistics = {
    'Statistic': ['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'],
    'YEAR': [116, 1958.5, 33.630343, 1901, 1929.75, 1958.5, 1987.25, 2016],
    'Actual Rainfall: JUN': [116.000000, 166.711207, 36.133349, 85.700000, 141.425000, 167.250000, 190.450000, 277.200000],
    'Actual Rainfall: JUL': [116.000000, 294.135345, 41.531085, 146.200000, 273.575000, 295.600000, 322.400000, 381.600000],
    'Actual Rainfall: AUG': [116.000000, 260.920690, 37.237717, 189.800000, 237.000000, 259.800000, 289.275000, 348.000000],
    'Actual Rainfall: SEPT': [116.000000, 173.710345, 37.492936, 95.100000, 143.375000, 173.650000, 201.925000, 283.100000],
    'Actual Rainfall: JUN-SEPT': [116.000000, 895.943966, 92.796977, 697.400000, 828.175000, 904.050000, 962.800000, 1124.200000],
    'Departure Percentage: JUN': [116.000000, -0.562931, 22.330344, -48.300000, -15.525000, -2.200000, 13.675000, 56.600000],
    'Departure Percentage: JUL': [116.000000, -2.203448, 14.009717, -54.200000, -8.550000, -2.000000, 6.425000, 26.600000],
    'Departure Percentage: AUG': [116.000000, 0.375000, 14.916037, -32.500000, -9.925000, -0.500000, 12.625000, 33.100000],
    'Departure Percentage: SEP': [116.000000, -1.219828, 22.628705, -44.700000, -19.525000, -1.850000, 15.250000, 64.500000],
    'Departure Percentage: JUN-SEPT': [116.000000, -0.976724, 10.031701, -24.900000, -8.300000, 0.350000, 5.300000, 22.900000]
}

# Bar Plot for Mean Rainfall
plt.figure(figsize=(10, 6))
plt.bar(statistics['Statistic'], statistics['Actual Rainfall: JUN'], alpha=0.8)
plt.xlabel('Statistic')
plt.ylabel('Mean Rainfall')
plt.title('Mean Rainfall in June')
plt.show()

# %% [markdown]
# ##  Univariate Analysis

# %% [markdown]
# ### YEAR

# %%
inp1.head()
# Out:
#    YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0  1901                 109.1                 241.4                 284.2
# 1  1902                 104.0                 283.7                 202.6
# 2  1903                 114.8                 293.0                 279.6
# 3  1904                 158.8                 266.4                 210.4
# 4  1905                  88.7                 252.5                 202.6
#
#    Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 0                  121.9                      756.6
# 1                  201.9                      792.1
# 2                  204.4                      891.9
# 3                  129.6                      765.2
# 4                  174.6                      718.5
#
#    Departure Percentage: JUN  Departure Percentage: JUL  \
# 0                      -29.9                      -16.7
# 1                      -33.6                       -2.0
# ...

# %%
inp1['YEAR'].value_counts()
# Out:
# 1901    1
# 1974    1
# 1986    1
# 1985    1
# 1984    1
#        ..
# 1935    1
# 1934    1
# 1933    1
# 1932    1
# 2016    1
# Name: YEAR, Length: 116, dtype: int64

# %%
inp1['YEAR'].unique()
# Out:
# array([1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911,
#        1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922,
#        1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933,
#        1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944,
#        1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955,
#        1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966,
#        1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977,
#        1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988,
#        1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016], dtype=int64)

# %% [markdown]
# Data of Rainfall in from 1901 to 2016 is recorded in this data set.

# %%
# Calculate the minimum year
min_year = inp1['YEAR'].min()

# Calculate the maximum year
max_year = inp1['YEAR'].max()

# Calculate the total number of years in the dataset
num_years = len(inp1['YEAR'].unique())

# Print the analysis results
print("Analysis of the YEAR column:")
print("----------------------------")
print(f"Minimum Year: {min_year}")
print(f"Maximum Year: {max_year}")
print(f"Total Number of Years: {num_years}")
# Out:
# Analysis of the YEAR column:
# ----------------------------
# Minimum Year: 1901
# Maximum Year: 2016
# Total Number of Years: 116

# %%
years = inp1['YEAR']

# Plot the line graph
plt.plot(years, marker='o', linestyle='-')

# Set the graph title and labels
plt.title("Yearly Distribution")
plt.xlabel("Year")
plt.ylabel("Count")

# Display the graph
plt.show()

# %%
# Count the occurrences of each year
year_counts = inp1['YEAR'].value_counts().sort_index()

# Create the bar chart
plt.bar(year_counts.index, year_counts.values)

# Set the graph title and labels
plt.title("Yearly Distribution")
plt.xlabel("Year")
plt.ylabel("Count")

# Rotate x-axis labels for better visibility (optional)
plt.xticks(rotation=90)

# Display the graph
plt.show()

# %% [markdown]
# ## Correlation

# %%
plt.figure(figsize=(12, 8))
corr_matrix = inp1.corr()
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation heatmap')
plt.show()

# %%
corr_matrix
# Out:
#                                     YEAR  Actual Rainfall: JUN  \
# YEAR                            1.000000              0.001225
# Actual Rainfall: JUN            0.001225              1.000000
# Actual Rainfall: JUL           -0.128658              0.009284
# Actual Rainfall: AUG           -0.074972              0.067129
# Actual Rainfall: SEPT          -0.022239             -0.039531
# Actual Rainfall: JUN-SEPT      -0.102884              0.399252
# Departure Percentage: JUN       0.027914              0.971379
# Departure Percentage: JUL      -0.093765             -0.030197
# Departure Percentage: AUG      -0.047534              0.053258
# Departure Percentage: SEP      -0.028808             -0.062195
# Departure Percentage: JUN-SEPT -0.066472              0.371962
#
#                                 Actual Rainfall: JUL  Actual Rainfall: AUG  \
# YEAR                                       -0.128658             -0.074972
# ...

# %% [markdown]
# "Actual Rainfall: JUN" has a weak positive correlation with "Actual Rainfall: JUL" (correlation coefficient: 0.009284) and "Actual Rainfall: AUG" (correlation coefficient: 0.067129). This indicates a slight tendency for these rainfall variables to increase together.
#
# "Actual Rainfall: JUL" has a moderate positive correlation with "Actual Rainfall: AUG" (correlation coefficient: 0.203205) and "Actual Rainfall: SEPT" (correlation coefficient: 0.335208). This suggests that higher rainfall in July is somewhat associated with higher rainfall in August and September.
#
# "Actual Rainfall: AUG" has a moderate positive correlation with "Actual Rainfall: SEPT" (correlation coefficient: 0.317483). This implies that increased rainfall in August is somewhat related to increased rainfall in September.
#
# "Actual Rainfall: JUN" and "Actual Rainfall: JUN-SEPT" have a moderate positive correlation (correlation coefficient: 0.399252), indicating that the rainfall during June has a moderate influence on the overall rainfall for the June-September period.
#
# "Actual Rainfall: JUN" has a strong positive correlation with "Departure Percentage: JUN" (correlation coefficient: 0.971379). This suggests that higher rainfall in June is closely associated with a higher departure percentage from the average rainfall in June.
#
# "Actual Rainfall: JUL" has a moderate positive correlation with "Departure Percentage: JUL" (correlation coefficient: 0.970037). This implies that higher rainfall in July is moderately associated with a higher departure percentage from the average rainfall in July.
#
# "Actual Rainfall: AUG" has a strong positive correlation with "Departure Percentage: AUG" (correlation coefficient: 0.977061). This indicates a close relationship between higher rainfall in August and a higher departure percentage from the average rainfall in August.
#
# "Actual Rainfall: SEPT" has a strong positive correlation with "Departure Percentage: SEP" (correlation coefficient: 0.989480). This suggests a strong association between higher rainfall in September and a higher departure percentage from the average rainfall in September.
#
# "Actual Rainfall: JUN-SEPT" has a strong positive correlation with "Departure Percentage: JUN-SEPT" (correlation coefficient: 0.961341). This indicates that higher overall rainfall for the June-September period is closely related to a higher departure percentage from the average rainfall for the same period.
#
# These correlations provide insights into the relationships between rainfall variables and departure percentages. It's important to note that correlation measures linear relationships and does not imply causation. Further analysis and domain knowledge are required to understand the underlying factors influencing these correlations.

# %% [markdown]
# ## Line plot of rainfall over the years

# %%
plt.figure(figsize=(12, 8))
plt.plot(inp1['YEAR'], inp1['Actual Rainfall: JUN'], label='JUN')
plt.plot(inp1['YEAR'], inp1['Actual Rainfall: JUL'], label='JUL')
plt.plot(inp1['YEAR'], inp1['Actual Rainfall: AUG'], label='AUG')
plt.plot(inp1['YEAR'], inp1['Actual Rainfall: SEPT'], label='SEPT')
plt.xlabel('Year')
plt.ylabel('Rainfall (mm)')
plt.title('Line plot of rainfall over the years')
plt.legend()
plt.show()

# %% [markdown]
# Rainfall over the years:
#
# The data includes information from the years 1901 to 2016, with a total of 116 observations.
#
# The mean rainfall values for June, July, August, and September are approximately 166.71 mm, 294.14 mm, 260.92 mm, and 173.71 mm, respectively.
#
# The overall rainfall for the June-September period has a mean of approximately 895.94 mm.
#
# The standard deviations indicate the variability of the rainfall values, with the highest variability observed for September and the lowest for June.
#
# The minimum and maximum values show the range of rainfall observed for each month and the June-September period.

# %% [markdown]
# # Box plot of departure percentages

# %%
plt.figure(figsize=(12, 8))
plt.boxplot(inp1[['Departure Percentage: JUN', 'Departure Percentage: JUL',
                  'Departure Percentage: AUG', 'Departure Percentage: SEP',
                  'Departure Percentage: JUN-SEPT']].values)
plt.xticks(range(1, 6), ['JUN', 'JUL', 'AUG', 'SEP', 'JUN-SEPT'])
plt.ylabel('Departure Percentage')
plt.title('Box plot of departure percentages')
plt.figure(figsize=(12, 8))
plt.show()

# %% [markdown]
# The departure percentages represent the deviation of the actual rainfall from the average rainfall for each month.
#
# The mean departure percentages for June, July, August, and September are approximately -0.56%, -2.20%, 0.38%, and -1.22%, respectively.
#
# The departure percentages have standard deviations that indicate the variability of deviations from the average rainfall for each month.
# .
# The minimum and maximum values show the range of departure percentages observed for each month.
